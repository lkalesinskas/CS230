# %%
from nilearn import plotting, image
import os

# %%
img1 = image.smooth_img('/Users/rohanpaul/Downloads/ABIDEII-BNI_1/29006/session_1/anat_1/anat.nii.gz', fwhm=5)
plotting.plot_img(img1, display_mode='y')


# plotting.plot_img()

# %%
hdr = img1.header

# %%
# Out:
# (193, 256, 256)

# %%
img = image.smooth_img('/Users/rohanpaul/Downloads/ABIDEII-BNI_1/29006/session_1/dti_1/dti.nii.gz', fwhm=5)
img_data = img.get_data()
img.shape
# Out:
# (192, 192, 48, 34)

# %%
img2 = image.smooth_img('/Users/rohanpaul/Downloads/AnnArbor_a/sub04111/anat/mprage_anonymized.nii.gz', fwhm=5)

# %%
plotting.plot_img(img2)
